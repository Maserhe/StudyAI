# %% [markdown]
# **线性回归**
# 损失函数降低到最小
# ![%E5%B1%8F%E5%B9%95%E5%BF%AB%E7%85%A7%202021-10-06%20%E4%B8%8B%E5%8D%887.02.06.png](attachment:%E5%B1%8F%E5%B9%95%E5%BF%AB%E7%85%A7%202021-10-06%20%E4%B8%8B%E5%8D%887.02.06.png)

# %% [markdown]
# 评估函数
# 1，均方差MSE
# 2,R方值
# ![image.png](attachment:image.png)

# %% [markdown]
# R方值接近1，说明拟合的越好
# 3，y` 和y的集中度越高越好
# 使用matplotlib进行绘图。scatter可以绘制散点图。
# plt.subplot(211) 2行1列，第1个字图。
# plt.subplot(212) 2行2列，第2个字图。

# %%
import pandas as pd
data = pd.read_csv('genetated_data.csv')
print(data)
# Out:
#    x   y
# 0  1   7
# 1  2   9
# 2  3  11
# 3  4  13
# 4  5  15

# %%
x = data.loc[:,'x']
y = data.loc[:,'y']
print(x, y)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: x, dtype: int64 0     7
# 1     9
# 2    11
# 3    13
# 4    15
# Name: y, dtype: int64

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(5,5))
plt.scatter(x, y)

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
x = np.array(x)
y = np.array(y)
x = x.reshape(-1, 1) 
y = y.reshape(-1, 1)
lr_model = LinearRegression()
lr_model.fit(x, y)
# Out:
# LinearRegression()

# %%
# 预测
from sklearn.linear_model import LinearRegression = lr_model.predict(x)
print(y)
pre = lr_model.predict([[3.5]])
print("预测的结果",pre)
# Out:
# [[ 7]
#  [ 9]
#  [11]
#  [13]
#  [15]]
# 预测的结果 [[12.]]

# %%
# a/b 打印
a = lr_model.coef_
b = lr_model.intercept_
print(a, b)
# 方程为 2x + 5
# Out:
# [[2.]] [5.]

# %%
from sklearn.metrics import mean_squared_error, r2_score
MSE = mean_squared_error(y, y_predict)
R2 = r2_score(y, y_predict)
print(MSE, R2)
# Out:
# 6.310887241768095e-31 1.0
